# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
final_data = pd.read_pickle(r'/Users/brittanyfreese/Documents/Career Foundry/11-2020 Instacart Basket Analysis/02 Data/Prepared Data/customer_orders_products.pkl')

# %%
final_data.head()
# Out:
#    user_id  Gender     State  Age date_joined  no_of_dependents fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017                 3    married
# 1    26711  Female  Missouri   48    1/1/2017                 3    married
# 2    26711  Female  Missouri   48    1/1/2017                 3    married
# 3    26711  Female  Missouri   48    1/1/2017                 3    married
# 4    26711  Female  Missouri   48    1/1/2017                 3    married
#
#    income  Unnamed: 0_x  order_id  ...    price_range_loc  busiest_days  \
# 0  165665        443895   2543867  ...  Mid-range product  Busiest days
# 1  165665        443897   1285508  ...  Mid-range product  Busiest days
# 2  165665        443898   2578584  ...  Mid-range product  Busiest days
# 3  165665        443892    423547  ...  Mid-range product  Busiest days
# 4  165665        443893   2524893  ...  Mid-range product  Busiest days
#
#    busiest_period_of_day  max_order  loyalty_flag  max_price  spending_flag  \
# ...

# %%
#Comparing Spending to State
final_data.groupby('spending_flag')['State'].value_counts()
# Out:
# spending_flag  State
# High Spender   Pennsylvania    666594
#                California      658772
#                Rhode Island    656240
#                Georgia         655797
#                New Mexico      653645
#                                 ...
# Low Spender    Florida            416
#                Pennsylvania       411
#                Wyoming            405
#                Texas              398
#                North Dakota       363
# Name: State, Length: 102, dtype: int64

# %%
#Creating Exclusion Flag
final_data.loc[final_data['max_order'] < 5, 'exclusion_flag'] = 'Low Activity Customer'

# %%
final_data.head(50)
# Out:
#     user_id  Gender       State  Age date_joined  no_of_dependents fam_status  \
# 0     26711  Female    Missouri   48    1/1/2017                 3    married
# 1     26711  Female    Missouri   48    1/1/2017                 3    married
# 2     26711  Female    Missouri   48    1/1/2017                 3    married
# 3     26711  Female    Missouri   48    1/1/2017                 3    married
# 4     26711  Female    Missouri   48    1/1/2017                 3    married
# 5     26711  Female    Missouri   48    1/1/2017                 3    married
# 6     26711  Female    Missouri   48    1/1/2017                 3    married
# 7     26711  Female    Missouri   48    1/1/2017                 3    married
# 8     26711  Female    Missouri   48    1/1/2017                 3    married
# 9     26711  Female    Missouri   48    1/1/2017                 3    married
# 10    26711  Female    Missouri   48    1/1/2017                 3    married
# ...

# %%
#Exclusing records for Low Activity Customers
mask = final_data['exclusion_flag'].isin(['Low Activity Customer'])
final_data[~mask]
# Out:
#           user_id  Gender     State  Age date_joined  no_of_dependents  \
# 0           26711  Female  Missouri   48    1/1/2017                 3
# 1           26711  Female  Missouri   48    1/1/2017                 3
# 2           26711  Female  Missouri   48    1/1/2017                 3
# 3           26711  Female  Missouri   48    1/1/2017                 3
# 4           26711  Female  Missouri   48    1/1/2017                 3
# ...           ...     ...       ...  ...         ...               ...
# 32404813   135902  Female  Missouri   66    4/1/2020                 2
# 32404814   135902  Female  Missouri   66    4/1/2020                 2
# 32404815   135902  Female  Missouri   66    4/1/2020                 2
# 32404816   135902  Female  Missouri   66    4/1/2020                 2
# 32404817   135902  Female  Missouri   66    4/1/2020                 2
#
#          fam_status  income  Unnamed: 0_x  order_id  ...  busiest_days  \
# ...

# %%
#Exporting this sample
path = (r'/Users/brittanyfreese/Documents/Career Foundry/11-2020 Instacart Basket Analysis/')

# %%
# Export data to pkl

final_data.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'lowactivityexcluded.pkl'))

# %%
pd.set_option('display.max_columns', None)
final_data.head()
# Out:
#    user_id  Gender     State  Age date_joined  no_of_dependents fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017                 3    married
# 1    26711  Female  Missouri   48    1/1/2017                 3    married
# 2    26711  Female  Missouri   48    1/1/2017                 3    married
# 3    26711  Female  Missouri   48    1/1/2017                 3    married
# 4    26711  Female  Missouri   48    1/1/2017                 3    married
#
#    income  Unnamed: 0_x  order_id eval_set  order_number  orders_day_of_week  \
# 0  165665        443895   2543867    prior             5                   1
# 1  165665        443897   1285508    prior             7                   5
# 2  165665        443898   2578584    prior             8                   1
# 3  165665        443892    423547    prior             2                   2
# 4  165665        443893   2524893    prior             3                   3
#
# ...

# %%
age_orders = final_data.groupby('Age')['order_number'].mean().reset_index()

# %%
age_orders.sort_values('order_number', ascending = False)
# Out:
#     Age  order_number
# 16   34     18.121511
# 4    22     17.960098
# 46   64     17.817539
# 39   57     17.802859
# 31   49     17.785441
# ..  ...           ...
# 6    24     16.466415
# 28   46     16.436903
# 37   55     16.392710
# 7    25     16.343800
# 12   30     16.252157
#
# [64 rows x 2 columns]

# %%
fam_status_orders = final_data.groupby('fam_status')['order_number'].mean()

# %%
fam_status_orders.head()
# Out:
# fam_status
# divorced/widowed                    17.275873
# living with parents and siblings    17.296372
# married                             17.088283
# single                              17.258766
# Name: order_number, dtype: float64

# %%
gender_orders = final_data.groupby('Gender')['order_number'].mean()

# %%
gender_orders.head()
# Out:
# Gender
# Female    17.213503
# Male      17.072089
# Name: order_number, dtype: float64

# %%
dependents_orders = final_data.groupby('no_of_dependents')['order_number'].mean()

# %%
dependents_orders.head()
# Out:
# no_of_dependents
# 0    17.264622
# 1    17.097906
# 2    17.063173
# 3    17.143361
# Name: order_number, dtype: float64

# %%
age_day = final_data.groupby('Age')['orders_day_of_week'].median()

# %%
age_day
# Out:
# Age
# 18    2
# 19    3
# 20    3
# 21    2
# 22    3
#      ..
# 77    2
# 78    3
# 79    3
# 80    3
# 81    3
# Name: orders_day_of_week, Length: 64, dtype: int64

# %%
fam_status_day = final_data.groupby('fam_status')['orders_day_of_week'].median()

# %%
fam_status_day
# Out:
# fam_status
# divorced/widowed                    3
# living with parents and siblings    3
# married                             3
# single                              3
# Name: orders_day_of_week, dtype: int64

# %%
final_data.loc[final_data['fam_status'] = 'single', 'Profile1'] = 'Single Adult'

# %%
final_data.loc[final_data['fam_status'] = 'married', 'Profile1'] = 'Married Adult'

# %%
final_data.head()
