# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'/Users/brittanyfreese/Documents/Career Foundry/11-2020 Instacart Basket Analysis/02 Data/Prepared Data/all_data_merged_added_col.pkl')

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
#Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'orders_day_of_week': ['mean']}
# Out:
#   File "<ipython-input-1-8755a4140d95>", line 1
#     df.groupby('department_id').agg({'orders_day_of_week': ['mean']}
#                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_pri'] > 40, 'loyalty_flag'] = 'Loyal customer'
